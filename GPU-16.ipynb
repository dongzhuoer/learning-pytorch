# %%
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # Chapter07 DCGAN

# %% [markdown]
# Refer to [GAN.py](GAN.py). Aadopted from [chapter7-DCGAN.ipynb](chapter7-DCGAN.ipynb):
#   - not use `batchs` to subset dataset
#   - much more epochs
#   - `if i % 200 == 0: print`
#   - `DataParallel()` n GPUs

# %%
Image.open('output-GPU16/GAN/fake_samples_epoch_00.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=530x530 at 0x7F626B2A2DD8>

# %%
Image.open('output-GPU16/GAN/fake_samples_epoch_04.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=530x530 at 0x7FE4579E14A8>

# %%
Image.open('output-GPU16/GAN/fake_samples_epoch_99.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=530x530 at 0x7FE4579E1518>

# %%
Image.open('output-GPU16/GAN/real_samples.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=530x530 at 0x7FE4579E1A90>

# %% [markdown]
# # Chapter07 Language Modeling

# %% [markdown]
# log
#
# ```
# epoch 001,   99/3481 batches, lr: 20.00, loss: 7.239
# ...
# epoch 001, 3399/3481 batches, lr: 20.00, loss: 5.358
# validation loss  5.30
# -----------------------------------------------------------------------------------------
# epoch 002,   99/3481 batches, lr: 20.00, loss: 5.432
# ...
# epoch 002, 3399/3481 batches, lr: 20.00, loss: 4.989
# validation loss  5.11
# -----------------------------------------------------------------------------------------
# epoch 003,   99/3481 batches, lr: 20.00, loss: 5.158
# ...
# epoch 003, 3399/3481 batches, lr: 20.00, loss: 4.842
# validation loss  5.02
# ...
# ...
# validation loss  4.64
# -----------------------------------------------------------------------------------------
# epoch 035,   99/3481 batches, lr: 0.08, loss: 4.473
# epoch 035,  199/3481 batches, lr: 0.08, loss: 4.333
# epoch 035,  299/3481 batches, lr: 0.08, loss: 4.318
# ...
# epoch 035, 3199/3481 batches, lr: 0.08, loss: 3.644
# epoch 035, 3299/3481 batches, lr: 0.08, loss: 4.276
# epoch 035, 3399/3481 batches, lr: 0.08, loss: 4.166
# validation loss  4.63
# ```
#
# Then it doesn't decrease
#
# ```
# Test loss  4.58
# ```

# %% [markdown]
# Generated setence
#
# ```
# <eos> = <unk> , <eos> <eos> the <unk> , a <unk> @-@ in who , drama , , <eos> was previously <unk> appearance action role in the film series ,
#
# @-@ 1960s . . and the <unk> were <unk> with the the @-@ . and the other was not by <eos> <unk> <unk> <unk> was was the by the and
#
# , the , the was the <unk> in in and and of of @-@ <unk> , who the of the <unk> part of <eos> <unk> <unk> was was the @.@
#
# than and @-@ year ( ( . the <unk> the <unk> of the up <unk> to of the <unk> @-@ loading , was out and by the <unk> <unk> ,
#
# , <eos> <unk> of the was had the the <unk> , <unk> , , was the of the <unk> system , . by be the . the . the a
#
# <unk> , . the city , <eos> <eos> = = = <unk> = the = = = = <eos> <eos> in december january , , was the no. in wanderers
#
# <unk> of <unk> <eos> <eos> first of the <unk> of was of of the of <unk> <unk> aspects . and which to the <unk> . and <unk> <unk> , and
#
# , <unk> @-@ , be so . <eos> was in the one on following year , the the first week , the was the by the <unk> the first was
#
# the <unk> . 's <unk> . the <unk> time @-@ <unk> ' the was as as a . . . and the also only popular <unk> of of the .
#
# @-@ and , and york , @-@ , that <unk> be be to the the country . championship . to the <unk> " " . " been a of the
#
# was the <unk> . the 's <unk> <unk> " and . <eos> <unk> noted <unk> <unk> wrote the with the fact of the <unk> @-@ , the <unk> of the
#
# <unk> francisco bay . <eos> 's were as the of and , <unk> were the <unk> were the the <unk> of the <unk> <unk> of the be the <unk> of
#
# , the <unk> summer draft <unk> . year . a <unk> @-@ 1 record . <eos> the 23 , 2011 , the was a <unk> with for <eos> <eos> =
#
# <unk> the <unk> . the of and the <unk> was the . the <unk> 's " . <eos> 's who , <unk> of on the <unk> than one first <unk>
#
# the to the . and the was not in after the death to <eos> <eos> , had the in be been the in the in the years the was be
#
# and by and and , and <unk> . . <eos> <unk> was based system was a of the most important and events events in the world . <eos> <eos> first
#
# the the <unk> . the the <eos> the was no between the two and , the , and <unk> <unk> <unk> the <unk> , as the , , <unk> <unk>
#
# , the <unk> of of 1 @,@ . <eos> the most of to the <eos> <unk> <unk> , <unk> war , and , and the . <eos> of <unk> school
#
# the , <eos> <eos> = = the toso = <eos> <eos> the nesbitt was born july april 2008 ) is a american professional ii listed , a @.@ 2 @-@
#
# and the of . the <eos> , the the were in the , the <unk> of not be the to be the and that the the <unk> had not to
# ```
